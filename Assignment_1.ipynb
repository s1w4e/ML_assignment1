# %% [markdown]
# <a href="https://colab.research.google.com/github/s1w4e/ML_assignment1/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the csv file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a2c2612d-717e-49c6-b101-9c706b39070c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2c2612d-717e-49c6-b101-9c706b39070c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
 #read the csv file
df = pd.read_csv(io.BytesIO(uploaded['data (1).csv']))
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#Show the basic statistical description about the data
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
#Check if the data has null values.
null=df.isnull().sum()
print(null)
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
#replace null values with mean
df.fillna(df.mean(), inplace=True)
df
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
null=df.isnull().sum()
print(null)
# Out:
# Duration    0
# Pulse       0
# Calories    0
# dtype: int64

# %%
#Select at least two columns and aggregate the data using: min, max, count, mean
import pandas as pd
selected_columns =['Duration','Pulse']
aggregated=df[selected_columns].agg(['min','max','count','mean'])
print(aggregated)
# Out:
#          Duration       Pulse
# min     15.000000   80.000000
# max    300.000000  159.000000
# count  169.000000  169.000000
# mean    63.846154  107.461538

# %%
#Filter the dataframe to select the rows with calories values between 500 and 1000.
import pandas as pd
result=df[(df['Calories']>500) & (df['Calories']<1000)]
print(result)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
#Filter the dataframe to select the rows with calories values > 500 and pulse < 100
import pandas as pd
result=df[(df['Calories']>500) & (df['Pulse']<100)]
print(result)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
#Create a new “df_modified” dataframe that contains all the columns from df except for “Maxpulse”
import pandas as pd
df_new=df.drop('Maxpulse',axis=1)
print(df_new)
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
#Delete the “Maxpulse” column from the main df dataframe
import pandas as pd
print(df)
df.drop('Maxpulse',axis=1,inplace=True)
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
#Convert the datatype of Calories column to int datatype
import pandas as pd
df['Calories']=df['Calories'].astype(int)
print(df)
# Out:
#      Duration  Pulse  Calories
# 0          60    110       409
# 1          60    117       479
# 2          60    103       340
# 3          45    109       282
# 4          45    117       406
# ..        ...    ...       ...
# 164        60    105       290
# 165        60    110       300
# 166        60    115       310
# 167        75    120       320
# 168        75    125       330
#
# [169 rows x 3 columns]

# %%
#printing the dataype
df.dtypes
# Out:
# Duration    int64
# Pulse       int64
# Calories    int64
# dtype: object
